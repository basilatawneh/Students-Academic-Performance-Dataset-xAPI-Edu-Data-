# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns; 
import random
data=pd.read_csv('xAPI-Edu-Data.csv')
data.head()
# Out:
#   gender NationalITy PlaceofBirth     StageID GradeID SectionID Topic  \
# 0      M          KW       KuwaIT  lowerlevel    G-04         A    IT
# 1      M          KW       KuwaIT  lowerlevel    G-04         A    IT
# 2      M          KW       KuwaIT  lowerlevel    G-04         A    IT
# 3      M          KW       KuwaIT  lowerlevel    G-04         A    IT
# 4      M          KW       KuwaIT  lowerlevel    G-04         A    IT
#
#   Semester Relation  raisedhands  VisITedResources  AnnouncementsView  \
# 0        F   Father           15                16                  2
# 1        F   Father           20                20                  3
# 2        F   Father           10                 7                  0
# 3        F   Father           30                25                  5
# 4        F   Father           40                50                 12
#
#    Discussion ParentAnsweringSurvey ParentschoolSatisfaction  \
# 0          20                   Yes                     Good
# 1          25                   Yes                     Good
# 2          30                    No                      Bad
# 3          35                    No                      Bad
# 4          50                    No                      Bad
#
#   StudentAbsenceDays Class
# 0            Under-7     M
# 1            Under-7     M
# 2            Above-7     L
# 3            Above-7     L
# 4            Above-7     M

# %%
data.describe()
# Out:
#        raisedhands  VisITedResources  AnnouncementsView  Discussion
# count   480.000000        480.000000         480.000000  480.000000
# mean     46.775000         54.797917          37.918750   43.283333
# std      30.779223         33.080007          26.611244   27.637735
# min       0.000000          0.000000           0.000000    1.000000
# 25%      15.750000         20.000000          14.000000   20.000000
# 50%      50.000000         65.000000          33.000000   39.000000
# 75%      75.000000         84.000000          58.000000   70.000000
# max     100.000000         99.000000          98.000000   99.000000

# %%
def cleanstage(x):
    if x=='lowerlevel' or x=='L':
        return 0
    elif x=="MiddleSchool"or x=='M':
        return 1
    else:
        return 2
data.StageID=data.StageID.apply(lambda y:cleanstage(y))
data['gender']=data.gender.apply(lambda x: 0 if x=='M' else 1)
data.ParentschoolSatisfaction=data.ParentschoolSatisfaction.apply(lambda x: 1 if x=='Good' else 0)
data.StudentAbsenceDays=data.StudentAbsenceDays.apply(lambda x: 0 if x=="Under-7" else 1)
data.Semester=data.Semester.apply(lambda x: 0 if x=='F' else 1)# 0=F - 1=S
data.GradeID=data.GradeID.apply(lambda x: int(x[2:]))
data.Relation=data.Relation.apply(lambda x: 0 if x=='Father' else 1)
data.ParentAnsweringSurvey=data.ParentAnsweringSurvey.apply(lambda x: 1 if x=='Yes' else 0)
data.Class=data.Class.apply(lambda x:cleanstage(x))
data
# Out:
#      gender NationalITy PlaceofBirth  StageID  GradeID SectionID      Topic  \
# 0         0          KW       KuwaIT        0        4         A         IT
# 1         0          KW       KuwaIT        0        4         A         IT
# 2         0          KW       KuwaIT        0        4         A         IT
# 3         0          KW       KuwaIT        0        4         A         IT
# 4         0          KW       KuwaIT        0        4         A         IT
# 5         1          KW       KuwaIT        0        4         A         IT
# 6         0          KW       KuwaIT        1        7         A       Math
# 7         0          KW       KuwaIT        1        7         A       Math
# 8         1          KW       KuwaIT        1        7         A       Math
# 9         1          KW       KuwaIT        1        7         B         IT
# 10        0          KW       KuwaIT        1        7         A       Math
# 11        0          KW       KuwaIT        1        7         B       Math
# 12        0          KW       KuwaIT        0        4         A         IT
# 13        0     lebanon      lebanon        1        8         A       Math
# 14        1          KW       KuwaIT        1        8         A       Math
# 15        1          KW       KuwaIT        1        6         A         IT
# 16        0          KW       KuwaIT        1        7         B         IT
# 17        0          KW       KuwaIT        1        7         A       Math
# 18        1          KW       KuwaIT        1        7         A         IT
# 19        0          KW       KuwaIT        1        7         B         IT
# 20        1          KW       KuwaIT        1        7         A         IT
# 21        1          KW       KuwaIT        1        7         B         IT
# 22        0          KW       KuwaIT        1        7         A         IT
# 23        0          KW       KuwaIT        1        7         A         IT
# 24        0          KW       KuwaIT        1        7         B         IT
# 25        0          KW       KuwaIT        1        7         A         IT
# 26        0          KW       KuwaIT        1        7         B         IT
# 27        0          KW       KuwaIT        1        8         A     Arabic
# 28        0          KW       KuwaIT        1        8         A    Science
# 29        1          KW       KuwaIT        1        8         A     Arabic
# ..      ...         ...          ...      ...      ...       ...        ...
# 450       1      Jordan       Jordan        1        8         A  Chemistry
# 451       1      Jordan       Jordan        1        8         A  Chemistry
# 452       1      Jordan       Jordan        1        8         A    Geology
# 453       1      Jordan       Jordan        1        8         A    Geology
# 454       1      Jordan       Jordan        1        8         A    History
# 455       1      Jordan       Jordan        1        8         A    History
# 456       1      Jordan       Jordan        1        8         A  Chemistry
# 457       1      Jordan       Jordan        1        8         A  Chemistry
# 458       0        Iraq         Iraq        1        8         A  Chemistry
# 459       0        Iraq         Iraq        1        8         A  Chemistry
# 460       0        Iraq         Iraq        1        8         A    Geology
# 461       0        Iraq         Iraq        1        8         A    Geology
# 462       0        Iraq         Iraq        1        8         A    History
# 463       0        Iraq         Iraq        1        8         A    History
# 464       1      Jordan       Jordan        1        8         A  Chemistry
# 465       1      Jordan       Jordan        1        8         A  Chemistry
# 466       1      Jordan       Jordan        1        8         A    Geology
# 467       1      Jordan       Jordan        1        8         A    Geology
# 468       1      Jordan       Jordan        1        8         A  Chemistry
# 469       1      Jordan       Jordan        1        8         A  Chemistry
# 470       0   Palestine       Jordan        1        8         A    History
# 471       0   Palestine       Jordan        1        8         A    History
# 472       0   Palestine    Palestine        1        8         A    Geology
# 473       0   Palestine    Palestine        1        8         A    Geology
# 474       1      Jordan       Jordan        1        8         A  Chemistry
# 475       1      Jordan       Jordan        1        8         A  Chemistry
# 476       1      Jordan       Jordan        1        8         A    Geology
# 477       1      Jordan       Jordan        1        8         A    Geology
# 478       1      Jordan       Jordan        1        8         A    History
# 479       1      Jordan       Jordan        1        8         A    History
#
#      Semester  Relation  raisedhands  VisITedResources  AnnouncementsView  \
# 0           0         0           15                16                  2
# 1           0         0           20                20                  3
# 2           0         0           10                 7                  0
# 3           0         0           30                25                  5
# 4           0         0           40                50                 12
# 5           0         0           42                30                 13
# 6           0         0           35                12                  0
# 7           0         0           50                10                 15
# 8           0         0           12                21                 16
# 9           0         0           70                80                 25
# 10          0         0           50                88                 30
# 11          0         0           19                 6                 19
# 12          0         0            5                 1                  0
# 13          0         0           20                14                 12
# 14          0         1           62                70                 44
# 15          0         0           30                40                 22
# 16          0         0           36                30                 20
# 17          0         0           55                13                 35
# 18          0         1           69                15                 36
# 19          0         1           70                50                 40
# 20          0         0           60                60                 33
# 21          0         0           10                12                  4
# 22          0         0           15                21                  2
# 23          0         0            2                 0                  2
# 24          0         0            0                 2                  3
# 25          0         0            8                 7                 30
# 26          0         0           19                19                 25
# 27          0         0           25                15                 12
# 28          0         0           75                85                 52
# 29          0         0           30                90                 33
# 15                    0      1
# 16                    1      1
# 17                    1      1
# 18                    0      1
# 19                    0      2
# 20                    1      1
# 21                    0      1
# 22                    0      1
# 23                    1      0
# 24                    1      0
# 25                    1      0
# 26                    0      1
# 27                    1      0
# 28                    0      1
# 29                    0      1
# ..                  ...    ...
# 450                   0      2
# 451                   0      2
# 452                   1      1
# 453                   1      1
# 454                   0      1
# 455                   0      1
# 456                   0      2
# 457                   0      2
# 458                   0      2
# 459                   0      2
# 460                   1      1
# 461                   1      1
# 462                   1      1
# 463                   1      1
# 464                   0      2
# 465                   0      2
# 466                   0      2
# 467                   0      2
# 468                   1      0
# 469                   1      0
# 470                   0      1
# 471                   0      1
# 472                   0      1
# 473                   0      1
# 474                   1      0
# 475                   1      0
# 476                   0      1
# 477                   0      1
# 478                   1      0
# 479                   1      0
#
# [480 rows x 17 columns]

# %%
data.Class.value_counts()
# Out:
# 1    211
# 2    142
# 0    127
# Name: Class, dtype: int64

# %%
corr = data.corr()
corr.style.background_gradient(cmap='coolwarm').set_precision(2)
# Out:
# <style  type="text/css" >
#     #T_ffaf08e8_985c_11e9_89c9_a8a7951f65ccrow0_col0 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_ffaf08e8_985c_11e9_89c9_a8a7951f65ccrow0_col1 {
#             background-color:  #5470de;
#             color:  #000000;
#         }    #T_ffaf08e8_985c_11e9_89c9_a8a7951f65ccrow0_col2 {
#             background-color:  #4c66d6;
#             color:  #000000;
#         }    #T_ffaf08e8_985c_11e9_89c9_a8a7951f65ccrow0_col3 {
#             background-color:  #4055c8;
#             color:  #f1f1f1;
#         }    #T_ffaf08e8_985c_11e9_89c9_a8a7951f65ccrow0_col4 {
#             background-color:  #adc9fd;
#             color:  #000000;
#         }    #T_ffaf08e8_985c_11e9_89c9_a8a7951f65ccrow0_col5 {
#             background-color:  #c6d6f1;
#             color:  #000000;
#         }    #T_ffaf08e8_985c_11e9_89c9_a8a7951f65ccrow0_col6 {
#             background-color:  #d6dce4;
#             color:  #000000;
#         }    #T_ffaf08e8_985c_11e9_89c9_a8a7951f65ccrow0_col7 {
#             background-color:  #97b8ff;
#             color:  #000000;
#         }    #T_ffaf08e8_985c_11e9_89c9_a8a7951f65ccrow0_col8 {
#             background-color:  #98b9ff;
#             color:  #000000;
#         }    #T_ffaf08e8_985c_11e9_89c9_a8a7951f65ccrow0_col9 {
#             background-color:  #84a7fc;
#             color:  #000000;
#         }    #T_ffaf08e8_985c_11e9_89c9_a8a7951f65ccrow0_col10 {
#             background-color:  #92b4fe;
#             color:  #000000;
#         }    #T_ffaf08e8_985c_11e9_89c9_a8a7951f65ccrow0_col11 {
#             background-color:  #96b7ff;
#             color:  #000000;
#         }    #T_ffaf08e8_985c_11e9_89c9_a8a7951f65ccrow0_col12 {
#             background-color:  #ebd3c6;
#             color:  #000000;
#         }    #T_ffaf08e8_985c_11e9_89c9_a8a7951f65ccrow1_col0 {
#             background-color:  #6c8ff1;
#             color:  #000000;
#         }    #T_ffaf08e8_985c_11e9_89c9_a8a7951f65ccrow1_col1 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_ffaf08e8_985c_11e9_89c9_a8a7951f65ccrow1_col2 {
#             background-color:  #c43032;
#             color:  #f1f1f1;
#         }    #T_ffaf08e8_985c_11e9_89c9_a8a7951f65ccrow1_col3 {
#             background-color:  #5875e1;
#             color:  #000000;
#         }    #T_ffaf08e8_985c_11e9_89c9_a8a7951f65ccrow1_col4 {
#             background-color:  #6a8bef;
#             color:  #000000;
#         }    #T_ffaf08e8_985c_11e9_89c9_a8a7951f65ccrow1_col5 {
#             background-color:  #cbd8ee;
#             color:  #000000;
#         }    #T_ffaf08e8_985c_11e9_89c9_a8a7951f65ccrow1_col6 {
#             background-color:  #b9d0f9;
#             color:  #000000;
#         }    #T_ffaf08e8_985c_11e9_89c9_a8a7951f65ccrow1_col7 {
#             background-color:  #b3cdfb;
#             color:  #000000;
#         }    #T_ffaf08e8_985c_11e9_89c9_a8a7951f65ccrow1_col8 {
#             background-color:  #a2c1ff;
#             color:  #000000;
#         }    #T_ffaf08e8_985c_11e9_89c9_a8a7951f65ccrow1_col9 {
#             background-color:  #9ebeff;
#             color:  #000000;
#         }    #T_ffaf08e8_985c_11e9_89c9_a8a7951f65ccrow1_col10 {
#             background-color:  #7295f4;
#             color:  #000000;
#         }    #T_ffaf08e8_985c_11e9_89c9_a8a7951f65ccrow1_col11 {
#             background-color:  #aac7fd;
#             color:  #000000;
#         }    #T_ffaf08e8_985c_11e9_89c9_a8a7951f65ccrow1_col12 {
#             background-color:  #cfdaea;
#             color:  #000000;
#         }    #T_ffaf08e8_985c_11e9_89c9_a8a7951f65ccrow2_col0 {
#             background-color:  #6c8ff1;
#             color:  #000000;
#         }    #T_ffaf08e8_985c_11e9_89c9_a8a7951f65ccrow2_col1 {
#             background-color:  #c43032;
#             color:  #f1f1f1;
#         }    #T_ffaf08e8_985c_11e9_89c9_a8a7951f65ccrow2_col2 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_ffaf08e8_985c_11e9_89c9_a8a7951f65ccrow2_col3 {
#             background-color:  #6687ed;
#             color:  #000000;
#         }    #T_ffaf08e8_985c_11e9_89c9_a8a7951f65ccrow2_col4 {
#             background-color:  #6a8bef;
#             color:  #000000;
#         }    #T_ffaf08e8_985c_11e9_89c9_a8a7951f65ccrow2_col5 {
#             background-color:  #cfdaea;
#             color:  #000000;
#         }    #T_ffaf08e8_985c_11e9_89c9_a8a7951f65ccrow2_col6 {
#             background-color:  #bbd1f8;
#             color:  #000000;
#         }    #T_ffaf08e8_985c_11e9_89c9_a8a7951f65ccrow2_col7 {
#             background-color:  #bcd2f7;
#             color:  #000000;
#         }    #T_ffaf08e8_985c_11e9_89c9_a8a7951f65ccrow2_col8 {
#             background-color:  #a7c5fe;
#             color:  #000000;
#         }    #T_ffaf08e8_985c_11e9_89c9_a8a7951f65ccrow2_col9 {
#             background-color:  #9ebeff;
#             color:  #000000;
#         }    #T_ffaf08e8_985c_11e9_89c9_a8a7951f65ccrow2_col10 {
#             background-color:  #7093f3;
#             color:  #000000;
#         }    #T_ffaf08e8_985c_11e9_89c9_a8a7951f65ccrow2_col11 {
#             background-color:  #afcafc;
#             color:  #000000;
#         }    #T_ffaf08e8_985c_11e9_89c9_a8a7951f65ccrow2_col12 {
#             background-color:  #cdd9ec;
#             color:  #000000;
#         }    #T_ffaf08e8_985c_11e9_89c9_a8a7951f65ccrow3_col0 {
#             background-color:  #6384eb;
#             color:  #000000;
#         }    #T_ffaf08e8_985c_11e9_89c9_a8a7951f65ccrow3_col1 {
#             background-color:  #6282ea;
#             color:  #000000;
#         }    #T_ffaf08e8_985c_11e9_89c9_a8a7951f65ccrow3_col2 {
#             background-color:  #6a8bef;
#             color:  #000000;
#         }    #T_ffaf08e8_985c_11e9_89c9_a8a7951f65ccrow3_col3 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_ffaf08e8_985c_11e9_89c9_a8a7951f65ccrow3_col4 {
#             background-color:  #9fbfff;
#             color:  #000000;
#         }    #T_ffaf08e8_985c_11e9_89c9_a8a7951f65ccrow3_col5 {
#             background-color:  #ccd9ed;
#             color:  #000000;
#         }    #T_ffaf08e8_985c_11e9_89c9_a8a7951f65ccrow3_col6 {
#             background-color:  #cedaeb;
#             color:  #000000;
#         }    #T_ffaf08e8_985c_11e9_89c9_a8a7951f65ccrow3_col7 {
#             background-color:  #d1dae9;
#             color:  #000000;
#         }    #T_ffaf08e8_985c_11e9_89c9_a8a7951f65ccrow3_col8 {
#             background-color:  #799cf8;
#             color:  #000000;
#         }    #T_ffaf08e8_985c_11e9_89c9_a8a7951f65ccrow3_col9 {
#             background-color:  #84a7fc;
#             color:  #000000;
#         }    #T_ffaf08e8_985c_11e9_89c9_a8a7951f65ccrow3_col10 {
#             background-color:  #6f92f3;
#             color:  #000000;
#         }    #T_ffaf08e8_985c_11e9_89c9_a8a7951f65ccrow3_col11 {
#             background-color:  #b2ccfb;
#             color:  #000000;
#         }    #T_ffaf08e8_985c_11e9_89c9_a8a7951f65ccrow3_col12 {
#             background-color:  #d7dce3;
#             color:  #000000;
#         }    #T_ffaf08e8_985c_11e9_89c9_a8a7951f65ccrow4_col0 {
#             background-color:  #aac7fd;
#             color:  #000000;
#         }    #T_ffaf08e8_985c_11e9_89c9_a8a7951f65ccrow4_col1 {
#             background-color:  #506bda;
#             color:  #000000;
#         }    #T_ffaf08e8_985c_11e9_89c9_a8a7951f65ccrow4_col2 {
#             background-color:  #485fd1;
#             color:  #f1f1f1;
#         }    #T_ffaf08e8_985c_11e9_89c9_a8a7951f65ccrow4_col3 {
#             background-color:  #7da0f9;
#             color:  #000000;
#         }    #T_ffaf08e8_985c_11e9_89c9_a8a7951f65ccrow4_col4 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_ffaf08e8_985c_11e9_89c9_a8a7951f65ccrow4_col5 {
#             background-color:  #ecd3c5;
#             color:  #000000;
#         }    #T_ffaf08e8_985c_11e9_89c9_a8a7951f65ccrow4_col6 {
#             background-color:  #edd1c2;
#             color:  #000000;
#         }    #T_ffaf08e8_985c_11e9_89c9_a8a7951f65ccrow4_col7 {
#             background-color:  #dcdddd;
#             color:

# %%
data.head(1)
# Out:
#    gender NationalITy PlaceofBirth  StageID  GradeID SectionID Topic  \
# 0       0          KW       KuwaIT        0        4         A    IT
#
#    Semester  Relation  raisedhands  VisITedResources  AnnouncementsView  \
# 0         0         0           15                16                  2
#
#    Discussion  ParentAnsweringSurvey  ParentschoolSatisfaction  \
# 0          20                      1                         1
#
#    StudentAbsenceDays Class
# 0                   0     M

# %%
d=data.groupby(['Class','StudentAbsenceDays'])['StudentAbsenceDays'].count()
#plt.bar(data.Class,d)

n_groups = 3
print(d)
means_frank = (d[0][0],d[1][0], d[2][0])
means_guido = (d[0][1], d[1][1], d[2][1])

# create plot
fig, ax = plt.subplots()
index = np.arange(n_groups)
bar_width = 0.35
opacity = 0.8

rects1 = plt.bar(index, means_frank, bar_width,
alpha=opacity,
color='b',
label='Under-7')

rects2 = plt.bar(index + bar_width, means_guido, bar_width,
alpha=opacity,
color='g',
label='above-7')

plt.xlabel('total grade (class)')
plt.ylabel('Absence Days')
plt.title('relation between the grade and absent days')
plt.xticks(index + bar_width, ('Low', 'Middle', 'High'))
plt.legend()

plt.tight_layout()
plt.show()
# Out:
# Class  StudentAbsenceDays
# 0      0                      11
#        1                     116
# 1      0                     140
#        1                      71
# 2      0                     138
#        1                       4
# Name: StudentAbsenceDays, dtype: int64

# %%
ax=data.Class[data.Relation==1].value_counts().plot(kind="bar",position=0,color='r',width=0.4)
data.Class[data.Relation==0].value_counts().plot(kind="bar",position=1,color='b',width=0.4)
plt.legend(['Mum','Father'])
ax.set_xticklabels(['High','Middle','Low'],rotation=0)
ax.set_title("relation between the grade and parent responsible")
# Out:
# Text(0.5, 1.0, 'relation between the grade and parent responsible')

# %%
ax=data.StageID[data.StudentAbsenceDays==0].value_counts().plot(kind="bar",position=0,color='r',width=0.4)
data.StageID[data.StudentAbsenceDays==1].value_counts().plot(kind="bar",position=1,color='b',width=0.4)
plt.legend(['under-7 days','above-7 days'])
ax.set_xticklabels(['High school','middle school','Low school'],rotation=0)
ax.set_title("relation between the absance days and  educational level")
# Out:
# Text(0.5, 1.0, 'relation between the absance days and  educational level')

# %%
               
ax=data.GradeID[data.StudentAbsenceDays==0].value_counts().plot(kind="bar",position=0,color='r',width=0.4)
data.GradeID[data.StudentAbsenceDays==1].value_counts().plot(kind="bar",position=1,color='b',width=0.4)
plt.legend(['under-7 days','above-7 days'])
#ax.set_xticklabels("",rotation=0)
ax.set_title("relation between the absance days and grade student belongs")
# Out:
# Text(0.5, 1.0, 'relation between the absance days and  educational level')

# %%
ax = sns.boxplot(x="StudentAbsenceDays", y="VisITedResources", data=data)#,order=["under-7 days", "above-7 days"])
#ax = sns.swarmplot(x="StudentAbsenceDays", y="VisITedResources", data=data, color=".25")
ax

# %%
ax = sns.boxplot(x="StudentAbsenceDays", y="AnnouncementsView", data=data)#,order=["under-7 days", "above-7 days"])
ax

# %%
ax = sns.boxplot(x="StudentAbsenceDays", y="raisedhands", data=data)#,order=["under-7 days", "above-7 days"])
ax

# %%
data.plot(kind='scatter',x='raisedhands',y='VisITedResources')
sns.lmplot(x='raisedhands',y='VisITedResources',data=data,fit_reg=True)

# %%
x = data[['GradeID','StageID','raisedhands','AnnouncementsView','Class','VisITedResources']]
y = data['StudentAbsenceDays']
x = sm.add_constant(x)
model = sm.Logit(y, x, missing='drop')
res=model.fit()
print(res.summary())
# Out:
# Optimization terminated successfully.
#          Current function value: 0.382417
#          Iterations 7
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:     StudentAbsenceDays   No. Observations:                  480
# Model:                          Logit   Df Residuals:                      473
# Method:                           MLE   Df Model:                            6
# Date:                Thu, 27 Jun 2019   Pseudo R-squ.:                  0.4311
# Time:                        00:56:40   Log-Likelihood:                -183.56
# converged:                       True   LL-Null:                       -322.64
#                                         LLR p-value:                 3.908e-57
# =====================================================================================
#                         coef    std err          z      P>|z|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# const                 2.0670      0.518      3.994      0.000       1.053       3.081
# GradeID               0.1847      0.157      1.175      0.240      -0.123       0.493
# StageID              -1.1690      0.723     -1.617      0.106      -2.586       0.248
# raisedhands          -0.0087      0.007     -1.312      0.190      -0.022       0.004
# AnnouncementsView     0.0198      0.007      2.739      0.006       0.006       0.034
# Class                -2.9431      0.332     -8.860      0.000      -3.594      -2.292
# VisITedResources     -0.0079      0.006     -1.337      0.181      -0.019       0.004
# =====================================================================================
